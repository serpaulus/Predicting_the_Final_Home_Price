# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline

# %%
train_df = pd.read_csv("Data_sets/train.csv")
test_df = pd.read_csv("Data_sets/test.csv")

# %% [markdown]
# # Clean the Train Dataset

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
print(train_df.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
train_df.columns.to_list()
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
#Filter the movies DataFrame for specific columns.

train_df.drop(
    'MSSubClass','Street','Alley','LotShape','LandContour','Utilities',
    'LandSlope','Condition1','Condition2','RoofStyle',
    'RoofMatl','Exterior1st','Exterior2nd','MasVnrType','MasVnrArea',
    'ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond',
    'BsmtExposure','BsmtFinType1','BsmtFinSF1','BsmtFinType2','BsmtFinSF2',
    'BsmtUnfSF','TotalBsmtSF','Heating','HeatingQC','CentralAir','Electrical',
    '1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','BsmtFullBath',
    'BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','KitchenAbvGr',
    'KitchenQual','TotRmsAbvGrd','Functional','Fireplaces','FireplaceQu',
    'GarageType','GarageYrBlt','GarageFinish','GarageCars','GarageArea',
    'GarageQual','GarageCond','PavedDrive','WoodDeckSF','OpenPorchSF',
    'EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','PoolQC','Fence',
    'MiscFeature','MiscVal', 'MoSold','YrSold')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-d5aaf4209f32> in <module>
#       1 #Filter the movies DataFrame for specific columns.
#       2
# ----> 3 train_df.drop(
#       4     'MSSubClass','Street','Alley','LotShape','LandContour','Utilities',
#       5     'LandSlope','Condition1','Condition2','RoofStyle',
#
# TypeError: drop() takes from 1 to 8 positional arguments but 67 were given

# %%
train_df.drop(train_df.columns[1:4], axis=1)
# Out:
#         Id  LotArea Street Alley LotShape LandContour Utilities LotConfig  \
# 0        1     8450   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1        2     9600   Pave   NaN      Reg         Lvl    AllPub       FR2
# 2        3    11250   Pave   NaN      IR1         Lvl    AllPub    Inside
# 3        4     9550   Pave   NaN      IR1         Lvl    AllPub    Corner
# 4        5    14260   Pave   NaN      IR1         Lvl    AllPub       FR2
# ...    ...      ...    ...   ...      ...         ...       ...       ...
# 1455  1456     7917   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1456  1457    13175   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1457  1458     9042   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1458  1459     9717   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1459  1460     9937   Pave   NaN      Reg         Lvl    AllPub    Inside
#
#      LandSlope Neighborhood  ... PoolArea PoolQC  Fence MiscFeature  MiscVal  \
# ...

# %%
train_df.drop(train_df.columns[1:10], axis=1)
# Out:
#         Id LotConfig Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0        1    Inside      CollgCr       Norm       Norm     1Fam     2Story
# 1        2       FR2      Veenker      Feedr       Norm     1Fam     1Story
# 2        3    Inside      CollgCr       Norm       Norm     1Fam     2Story
# 3        4    Corner      Crawfor       Norm       Norm     1Fam     2Story
# 4        5       FR2      NoRidge       Norm       Norm     1Fam     2Story
# ...    ...       ...          ...        ...        ...      ...        ...
# 1455  1456    Inside      Gilbert       Norm       Norm     1Fam     2Story
# 1456  1457    Inside       NWAmes       Norm       Norm     1Fam     1Story
# 1457  1458    Inside      Crawfor       Norm       Norm     1Fam     2Story
# 1458  1459    Inside        NAmes       Norm       Norm     1Fam     1Story
# 1459  1460    Inside      Edwards       Norm       Norm     1Fam     1Story
#
# ...

# %%
train_df['HouseStyle'].value_counts().to_frame()
# Out:
#         HouseStyle
# 1Story         726
# 2Story         445
# 1.5Fin         154
# SLvl            65
# SFoyer          37
# 1.5Unf          14
# 2.5Unf          11
# 2.5Fin           8

# %% [markdown]
# # Clean the Test Dataset

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# ...

# %% [markdown]
# # Connect Pandas to Postgres

# %%
from sqlalchemy import create_engine
from config import db_password
import psycopg2

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/train_data"

# %%
engine = create_engine(db_string)
