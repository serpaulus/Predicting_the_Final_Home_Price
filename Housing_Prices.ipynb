# %%
import pandas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv("Data_sets/train.csv")
test_df = pd.read_csv("Data_sets/test.csv")

# %% [markdown]
# # Clean the Train Dataset

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
print(train_df.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
train_df.columns.to_list()
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SaleType',
#  'SaleCondition',
#  'SalePrice']

# %%
aa = train_df.isnull().sum()
aa[aa>0].sort_values(ascending=False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
train_df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
clean_data_df = { 'Id': 'Id',
                 'HouseStyle': 'HouseStyle',
                 'BedroomAbvGr': '# of Bedrooms',
                 'FullBath': 'Full Bath',
                 'HalfBath': 'Half Bath',
                 'GarageType': 'Garage Type',
                 'GrLivArea': 'LivingArea Sqft',
                 '1stFlrSF': '1stFloor Sqft',
                 '2ndFlrSF':'2ndFloor Sqft' ,
                 'LotConfig': 'Lot Location',
                 'YearBuilt': 'YearBuilt',
                 'YearRemodAdd': 'Year Remodeled',
                 'Exterior1st': '1stExterior',
                 'Exterior2nd': '2ndExterior',
                 'MasVnrType': 'Masonry Veneer Type',
                 'Neighborhood': 'Neighborhood',
                 'OverallQual': 'Overall Quality',
                 'OverallCond': 'Overall Condition',
                 'SaleCondition': 'Sale Condition',
                 'SalePrice': 'Sale Price'
    
}
train_df.rename(columns =clean_data_df, inplace = True)
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  Sale Condition  Sale Price
# 0   2008        WD          Normal      208500
# 1   2007        WD          Normal      181500
# 2   2008        WD          Normal      223500
# 3   2006        WD         Abnorml      140000
# 4   2008        WD          Normal      250000
#
# [5 rows x 81 columns]

# %%
#Add the Living Area Sqft, 1st floor and 2nd floor sqft to get the total sqft
sum_column = train_df["LivingArea Sqft"] + train_df["1stFloor Sqft"] + train_df["2ndFloor Sqft"]
train_df["Total Sqft"] = sum_column
print(train_df)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolQC  Fence MiscFeature MiscVal MoSold  \
# 0            Lvl    AllPub  ...    NaN    NaN         NaN       0      2
# 1            Lvl    AllPub  ...    NaN    NaN         NaN       0      5
# 2            Lvl    AllPub  ...    NaN    NaN         NaN       0      9
# 3            Lvl    AllPub  ...    NaN    NaN         NaN       0      2
# 4            Lvl    AllPub  ...    NaN    NaN         NaN       0     12
# ...          ...       ...  ...    ...    ...         ...     ...    ...
# 1455         Lvl    AllPub  ...    NaN    NaN         NaN       0      8
# 1456         Lvl    AllPub  ...    NaN  MnPrv         NaN       0      2
# 1457         Lvl    AllPub  ...    NaN  GdPrv        Shed    2500      5
# 1458         Lvl    AllPub  ...    NaN    NaN         NaN       0      4
# 1459         Lvl    AllPub  ...    NaN    NaN         NaN       0      6
#
#      YrSold SaleType  Sale Condition  Sale Price  Total Sqft
# 0      2008       WD          Normal      208500        3420
# 1      2007       WD          Normal      181500        2524
# 2      2008       WD          Normal      223500        3572
# 3      2006       WD         Abnorml      140000        3434
# 4      2008       WD          Normal      250000        4396
# ...     ...      ...             ...         ...         ...
# 1455   2007       WD          Normal      175000        3294
# 1456   2010       WD          Normal      210000        4146
# 1457   2010       WD          Normal      266500        4680
# 1458   2010       WD          Normal      142125        2156
# 1459   2008       WD          Normal      147500        2512
#
# [1460 rows x 82 columns]

# %%
#Filter the train DataFrame for specific columns.
clean_train_df = train_df[[
    'Id','HouseStyle','# of Bedrooms','Full Bath','Half Bath','Garage Type',
    'LivingArea Sqft','1stFloor Sqft','2ndFloor Sqft' ,'Total Sqft','Lot Location','YearBuilt',
    'Year Remodeled','1stExterior','2ndExterior','Masonry Veneer Type','Neighborhood',
    'Overall Quality','Overall Condition','Sale Condition', 'Sale Price'
    ]]

clean_train_df
# Out:
#         Id HouseStyle  # of Bedrooms  Full Bath  Half Bath Garage Type  \
# 0        1     2Story              3          2          1      Attchd
# 1        2     1Story              3          2          0      Attchd
# 2        3     2Story              3          2          1      Attchd
# 3        4     2Story              3          1          0      Detchd
# 4        5     2Story              4          2          1      Attchd
# ...    ...        ...            ...        ...        ...         ...
# 1455  1456     2Story              3          2          1      Attchd
# 1456  1457     1Story              3          2          0      Attchd
# 1457  1458     2Story              4          2          0      Attchd
# 1458  1459     1Story              2          1          0      Attchd
# 1459  1460     1Story              3          1          1      Attchd
#
#       LivingArea Sqft  1stFloor Sqft  2ndFloor Sqft  Total Sqft  ...  \
# 0                1710            856            854        3420  ...
# 1                1262           1262              0        2524  ...
# 2                1786            920            866        3572  ...
# 3                1717            961            756        3434  ...
# 4                2198           1145           1053        4396  ...
# ...               ...            ...            ...         ...  ...
# 1455             1647            953            694        3294  ...
# 1456             2073           2073              0        4146  ...
# 1457             2340           1188           1152        4680  ...
# 1458             1078           1078              0        2156  ...
# 1459             1256           1256              0        2512  ...
#
#      YearBuilt  Year Remodeled  1stExterior 2ndExterior Masonry Veneer Type  \
# 0         2003            2003      VinylSd     VinylSd             BrkFace
# 1         1976            1976      MetalSd     MetalSd                None
# 2         2001            2002      VinylSd     VinylSd             BrkFace
# 3         1915            1970      Wd Sdng     Wd Shng                None
# 4         2000            2000      VinylSd     VinylSd             BrkFace
# ...        ...             ...          ...         ...                 ...
# 1455      1999            2000      VinylSd     VinylSd                None
# 1456      1978            1988      Plywood     Plywood               Stone
# 1457      1941            2006      CemntBd     CmentBd                None
# 1458      1950            1996      MetalSd     MetalSd                None
# 1459      1965            1965      HdBoard     HdBoard                None
#
#      Neighborhood Overall Quality  Overall Condition  Sale Condition  \
# 0         CollgCr               7                  5          Normal
# 1         Veenker               6                  8          Normal
# 2         CollgCr               7                  5          Normal
# 3         Crawfor               7                  5         Abnorml
# 4         NoRidge               8                  5          Normal
# ...           ...             ...                ...             ...
# 1455      Gilbert               6                  5          Normal
# 1456       NWAmes               6                  6          Normal
# 1457      Crawfor               7                  9          Normal
# 1458        NAmes               5                  6          Normal
# 1459      Edwards               5                  6          Normal
#
#      Sale Price
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 21 columns]

# %%
#Add the Living Area Sqft, 1st floor and 2nd floor sqft to get the total sqft
#sum_column = clean_train_df["LivingArea Sqft"] + clean_train_df["1stFloor Sqft"] + clean_train_df["2ndFloor Sqft"]
#clean_train_df["Total Sqft"] = sum_column
#print(clean_train_df)

# %%
clean_train_df.columns[clean_train_df.dtypes == object]
# Out:
# Index(['HouseStyle', 'Garage Type', 'Lot Location', '1stExterior',
#        '2ndExterior', 'Masonry Veneer Type', 'Neighborhood', 'Sale Condition'],
#       dtype='object')

# %%
clean_train_df.isnull().sum()[clean_train_df.isnull().sum()>0]
# Out:
# Garage Type            81
# Masonry Veneer Type     8
# dtype: int64

# %%
overall_features = clean_train_df[['Overall Quality', 'Overall Condition']]
display(overall_features.info())
display(overall_features.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Overall Quality    1460 non-null   int64
#  1   Overall Condition  1460 non-null   int64
# dtypes: int64(2)
# memory usage: 22.9 KB
# None
#    Overall Quality  Overall Condition
# 0                7                  5
# 1                6                  8
# 2                7                  5
# 3                7                  5
# 4                8                  5

# %%
#filling in other missing values 
cols = ["Garage Type", "Masonry Veneer Type"]
for col in cols:
    clean_train_df[col].fillna(0, inplace=True)
# Out:
# /Users/adebolaayilumo/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
clean_train_df.isnull().sum()[clean_train_df.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
clean_train_df['HouseStyle'].value_counts().to_frame()
# Out:
#         HouseStyle
# 1Story         726
# 2Story         445
# 1.5Fin         154
# SLvl            65
# SFoyer          37
# 1.5Unf          14
# 2.5Unf          11
# 2.5Fin           8

# %%
clean_train_df['# of Bedrooms'].value_counts().to_frame()
# Out:
#    # of Bedrooms
# 3            804
# 2            358
# 4            213
# 1             50
# 5             21
# 6              7
# 0              6
# 8              1

# %%
exterior_features = clean_train_df[['1stExterior', '2ndExterior']]
display(exterior_features.info())
display(exterior_features.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   1stExterior  1460 non-null   object
#  1   2ndExterior  1460 non-null   object
# dtypes: object(2)
# memory usage: 22.9+ KB
# None
#   1stExterior 2ndExterior
# 0     VinylSd     VinylSd
# 1     MetalSd     MetalSd
# 2     VinylSd     VinylSd
# 3     Wd Sdng     Wd Shng
# 4     VinylSd     VinylSd

# %%
bathroom_features = clean_train_df[['Full Bath', 'Half Bath']]
display(bathroom_features.info())
display(bathroom_features.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Full Bath  1460 non-null   int64
#  1   Half Bath  1460 non-null   int64
# dtypes: int64(2)
# memory usage: 22.9 KB
# None
#    Full Bath  Half Bath
# 0          2          1
# 1          2          0
# 2          2          1
# 3          1          0
# 4          2          1

# %%
sum_column = clean_train_df["LivingArea Sqft"] + clean_train_df["1stFloor Sqft"] + clean_train_df["2ndFloor Sqft"]
clean_train_df["Total Sqft"] = sum_column
print(clean_train_df)
# Out:
#         Id HouseStyle  # of Bedrooms  Full Bath  Half Bath Garage Type  \
# 0        1     2Story              3          2          1      Attchd
# 1        2     1Story              3          2          0      Attchd
# 2        3     2Story              3          2          1      Attchd
# 3        4     2Story              3          1          0      Detchd
# 4        5     2Story              4          2          1      Attchd
# ...    ...        ...            ...        ...        ...         ...
# 1455  1456     2Story              3          2          1      Attchd
# 1456  1457     1Story              3          2          0      Attchd
# 1457  1458     2Story              4          2          0      Attchd
# 1458  1459     1Story              2          1          0      Attchd
# 1459  1460     1Story              3          1          1      Attchd
#
#       LivingArea Sqft  1stFloor Sqft  2ndFloor Sqft  Total Sqft  ...  \
# 0                1710            856            854        3420  ...
# 1                1262           1262              0        2524  ...
# 2                1786            920            866        3572  ...
# 3                1717            961            756        3434  ...
# 4                2198           1145           1053        4396  ...
# ...               ...            ...            ...         ...  ...
# 1455             1647            953            694        3294  ...
# 1456             2073           2073              0        4146  ...
# 1457             2340           1188           1152        4680  ...
# 1458             1078           1078              0        2156  ...
# 1459             1256           1256              0        2512  ...
#
#      YearBuilt  Year Remodeled  1stExterior 2ndExterior Masonry Veneer Type  \
# 0         2003            2003      VinylSd     VinylSd             BrkFace
# 1         1976            1976      MetalSd     MetalSd                None
# 2         2001            2002      VinylSd     VinylSd             BrkFace
# 3         1915            1970      Wd Sdng     Wd Shng                None
# 4         2000            2000      VinylSd     VinylSd             BrkFace
# ...        ...             ...          ...         ...                 ...
# 1455      1999            2000      VinylSd     VinylSd                None
# 1456      1978            1988      Plywood     Plywood               Stone
# 1457      1941            2006      CemntBd     CmentBd                None
# 1458      1950            1996      MetalSd     MetalSd                None
# 1459      1965            1965      HdBoard     HdBoard                None
#
#      Neighborhood Overall Quality  Overall Condition  Sale Condition  \
# 0         CollgCr               7                  5          Normal
# 1         Veenker               6                  8          Normal
# 2         CollgCr               7                  5          Normal
# 3         Crawfor               7                  5         Abnorml
# 4         NoRidge               8                  5          Normal
# ...           ...             ...                ...             ...
# 1455      Gilbert               6                  5          Normal
# 1456       NWAmes               6                  6          Normal
# 1457      Crawfor               7                  9          Normal
# 1458        NAmes               5                  6          Normal
# 1459      Edwards               5                  6          Normal
#
#      Sale Price
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 21 columns]
# <ipython-input-25-bb54297ceef8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_train_df["Total Sqft"] = sum_column

# %%
clean_train_df.shape
# Out:
# (1460, 21)

# %%
clean_train_df.describe()
# Out:
#                 Id  # of Bedrooms    Full Bath    Half Bath  LivingArea Sqft  \
# count  1460.000000    1460.000000  1460.000000  1460.000000      1460.000000
# mean    730.500000       2.866438     1.565068     0.382877      1515.463699
# std     421.610009       0.815778     0.550916     0.502885       525.480383
# min       1.000000       0.000000     0.000000     0.000000       334.000000
# 25%     365.750000       2.000000     1.000000     0.000000      1129.500000
# 50%     730.500000       3.000000     2.000000     0.000000      1464.000000
# 75%    1095.250000       3.000000     2.000000     1.000000      1776.750000
# max    1460.000000       8.000000     3.000000     2.000000      5642.000000
#
#        1stFloor Sqft  2ndFloor Sqft    Total Sqft    YearBuilt  \
# count    1460.000000    1460.000000   1460.000000  1460.000000
# mean     1162.626712     346.992466   3025.082877  1971.267808
# std       386.587738     436.528436   1045.522787    30.202904
# min       334.000000       0.000000    668.000000  1872.000000
# 25%       882.000000       0.000000   2252.000000  1954.000000
# 50%      1087.000000       0.000000   2916.000000  1973.000000
# 75%      1391.250000     728.000000   3553.500000  2000.000000
# max      4692.000000    2065.000000  11284.000000  2010.000000
#
#        Year Remodeled  Overall Quality  Overall Condition     Sale Price
# count     1460.000000      1460.000000        1460.000000    1460.000000
# mean      1984.865753         6.099315           5.575342  180921.195890
# std         20.645407         1.382997           1.112799   79442.502883
# min       1950.000000         1.000000           1.000000   34900.000000
# 25%       1967.000000         5.000000           5.000000  129975.000000
# 50%       1994.000000         6.000000           5.000000  163000.000000
# 75%       2004.000000         7.000000           6.000000  214000.000000
# max       2010.000000        10.000000           9.000000  755000.000000

# %%
import numpy as np

# %%
sqft_df = clean_train_df[['# of Bedrooms','Total Sqft', 'Sale Price']]
sqft_df = sqft_df[~sqft_df['Sale Price'].isnull()]
sqft_vars = list(sqft_df)
del sqft_vars[-1]

sqft_summary = []

for sqft_type in sqft_vars:
    corr_val = np.corrcoef(sqft_df[sqft_type], sqft_df['Sale Price'])[1][0]
    sqft_summary.append(corr_val)
    
pd.DataFrame([sqft_summary], columns=sqft_vars, index=['SalePrice Correlation'])
# Out:
#                        # of Bedrooms  Total Sqft
# SalePrice Correlation       0.168213    0.713501

# %%
sqft_df
# Out:
#       # of Bedrooms  Total Sqft  Sale Price
# 0                 3        3420      208500
# 1                 3        2524      181500
# 2                 3        3572      223500
# 3                 3        3434      140000
# 4                 4        4396      250000
# ...             ...         ...         ...
# 1455              3        3294      175000
# 1456              3        4146      210000
# 1457              4        4680      266500
# 1458              2        2156      142125
# 1459              3        2512      147500
#
# [1460 rows x 3 columns]

# %%
# kernel density plot
sns.distplot(clean_train_df.Sale Price,fit=norm);
plt.ylabel =('Frequency')
plt.title = ('Sale Price Distribution');
#QQ plot
fig = plt.figure()
res = stats.probplot(clean_train_df['Sale Price'], plot=plt)
plt.show()

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
features_df = pd.DataFrame(clean_train_df, columns=['HouseStyle','# of Bedrooms', 'Full Bath', 'Half Bath','Total Sqft'])
features_df.set_index(features_df['HouseStyle'], inplace=True)
features_df=features_df[['HouseStyle','# of Bedrooms', 'Full Bath', 'Half Bath','Total Sqft']]
features_df
# Out:
#            HouseStyle  # of Bedrooms  Full Bath  Half Bath  Total Sqft
# HouseStyle
# 2Story         2Story              3          2          1        3420
# 1Story         1Story              3          2          0        2524
# 2Story         2Story              3          2          1        3572
# 2Story         2Story              3          1          0        3434
# 2Story         2Story              4          2          1        4396
# ...               ...            ...        ...        ...         ...
# 2Story         2Story              3          2          1        3294
# 1Story         1Story              3          2          0        4146
# 2Story         2Story              4          2          0        4680
# 1Story         1Story              2          1          0        2156
# 1Story         1Story              3          1          1        2512
#
# [1460 rows x 5 columns]

# %% [markdown]
# # Clean the Test Dataset

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
# 2       0      3    2010        WD         Normal
# 3       0      6    2010        WD         Normal
# 4       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %%
test_df.describe()

# %%
clean_testdata_df = { 'Id': 'Id',
                 'HouseStyle': 'HouseStyle',
                 'BedroomAbvGr': '# of Bedrooms',
                 'FullBath': 'Full Bath',
                 'HalfBath': 'Half Bath',
                 'GarageType': 'Garage Type',
                 'GrLivArea': 'LivingArea Sqft',
                 '1stFlrSF': '1stFloor Sqft',
                 '2ndFlrSF':'2ndFloor Sqft' ,
                 'LotConfig': 'Lot Location',
                 'YearBuilt': 'YearBuilt',
                 'YearRemodAdd': 'Year Remodeled',
                 'Exterior1st': '1stExterior',
                 'Exterior2nd': '2ndExterior',
                 'MasVnrType': 'Masonry Veneer Type',
                 'Neighborhood': 'Neighborhood',
                 'OverallQual': 'Overall Quality',
                 'OverallCond': 'Overall Condition',
                 'SaleCondition': 'Sale Condition'
    
}
test_df.rename(columns =clean_testdata_df, inplace = True)
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  Sale Condition
# 0       0      6    2010        WD          Normal
# 1   12500      6    2010        WD          Normal
# 2       0      3    2010        WD          Normal
# 3       0      6    2010        WD          Normal
# 4       0      1    2010        WD          Normal
#
# [5 rows x 80 columns]

# %%
clean_test_df = test_df[[
    'Id','HouseStyle','# of Bedrooms','Full Bath','Half Bath','Garage Type',
    'LivingArea Sqft','1stFloor Sqft','2ndFloor Sqft' ,'Lot Location','YearBuilt',
    'Year Remodeled','1stExterior','2ndExterior','Masonry Veneer Type','Neighborhood',
    'Overall Quality','Overall Condition','Sale Condition'
    ]]

# %%
clean_test_df

# %%
clean_test_df.columns[clean_test_df.dtypes == object]

# %%
clean_test_df.isnull().sum()[clean_test_df.isnull().sum()>0]

# %%
overall_features = clean_test_df[['Overall Quality', 'Overall Condition']]
display(overall_features.info())
display(overall_features.head())

# %%
#filling in other missing values 
cols = ["Garage Type", "Masonry Veneer Type"]
for col in cols:
    clean_test_df[col].fillna(0, inplace=True)

# %%
# fill in with mode
cols2 = ['1stExterior','2ndExterior']
for col in cols2:
    clean_test_df[col].fillna(clean_test_df[col].mode()[0], inplace=True)

# %%
clean_test_df.isnull().sum()[clean_test_df.isnull().sum()>0]

# %%
clean_test_df

# %% [markdown]
# # Connect Pandas to Postgres

# %%
from sqlalchemy import create_engine
from config import db_password
import psycopg2

# %%
db_string = f"postgresql://postgres:{db_password}@housing-prices.ctpruadwlamv.us-east-2.rds.amazonaws.com:5432/housing-prices"
engine = create_engine(db_string)

# %%
#mode = "append"
#jdbc_url="postgresql://housing-prices.ctpruadwlamv.us-east-2.rds.amazonaws.com:5432/housing-prices"
#config = {"user":"postgres", 
          #"password": "dataanalytics", 
          #"driver":"org.postgresql.Driver"}

# %%
clean_train_df.to_sql(name='clean_train', con=engine, if_exists='append',index=False)

# %%
clean_test_df.to_sql(name='clean_test', con=engine)
