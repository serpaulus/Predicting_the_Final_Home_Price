# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
train_df = pd.read_csv("Data_sets/train.csv")
test_df = pd.read_csv("Data_sets/test.csv")

# %% [markdown]
# # Clean the Train Dataset

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
print(train_df.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
train_df.columns.to_list()
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
aa = train_df.isnull().sum()
aa[aa>0].sort_values(ascending=False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
train_df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
clean_data_df = { 'Id': 'Id',
                 'HouseStyle': 'HouseStyle',
                 'BedroomAbvGr': 'No_of_Bedrooms',
                 'FullBath': 'Full_Bath',
                 'HalfBath': 'Half_Bath',
                 'GarageType': 'Garage_Type',
                 'GrLivArea': 'Total_Sqft',
                 'LotConfig': 'Lot_Location',
                 'YearBuilt': 'YearBuilt',
                 'YearRemodAdd': 'Year_Remodeled',
                 'Exterior1st': 'FirstExterior',
                 'Exterior2nd': 'SecondExterior',
                 'MasVnrType': 'MasonryVeneer_Type',
                 'Neighborhood': 'Neighborhood',
                 'OverallQual': 'Overall_Quality',
                 'OverallCond': 'Overall_Condition',
                 'SaleCondition': 'Sale_Condition',
                 'SalePrice': 'Sale_Price'
    
}
train_df.rename(columns =clean_data_df, inplace = True)
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  Sale_Condition  Sale_Price
# ...

# %%
#Add the Living Area Sqft, 1st floor and 2nd floor sqft to get the total sqft
sum_column = train_df["LivingArea_Sqft"] + train_df["1stFloor_Sqft"] + train_df["2ndFloor_Sqft"]
train_df["Total_Sqft"] = sum_column
print(train_df)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#Filter the train DataFrame for specific columns.
clean_train_df = train_df[[
    'Id','HouseStyle','No_of_Bedrooms','Full_Bath','Half_Bath','Garage_Type',
    'LivingArea_Sqft','1stFloor_Sqft','2ndFloor_Sqft' ,'Total_Sqft','Lot_Location','YearBuilt',
    'Year_Remodeled','FirstExterior','SecondExterior','MasonryVeneer_Type','Neighborhood',
    'Overall_Quality','Overall_Condition','Sale_Condition', 'Sale_Price'
    ]]

clean_train_df
# Out:
#         Id HouseStyle  No_of_Bedrooms  Full_Bath  Half_Bath Garage_Type  \
# 0        1     2Story               3          2          1      Attchd
# 1        2     1Story               3          2          0      Attchd
# 2        3     2Story               3          2          1      Attchd
# 3        4     2Story               3          1          0      Detchd
# 4        5     2Story               4          2          1      Attchd
# ...    ...        ...             ...        ...        ...         ...
# 1455  1456     2Story               3          2          1      Attchd
# 1456  1457     1Story               3          2          0      Attchd
# 1457  1458     2Story               4          2          0      Attchd
# 1458  1459     1Story               2          1          0      Attchd
# 1459  1460     1Story               3          1          1      Attchd
#
#       LivingArea_Sqft  1stFloor_Sqft  2ndFloor_Sqft  Total_Sqft  ...  \
# ...

# %%
quality_pivot = clean_train_df.pivot_table(index='Overall_Quality',values='Sale_Price', aggfunc=np.median)
quality_pivot
# Out:
#                  Sale_Price
# Overall_Quality
# 1                     50150
# 2                     60000
# 3                     86250
# 4                    108000
# 5                    133000
# 6                    160000
# 7                    200141
# 8                    269750
# 9                    345000
# 10                   432390

# %%
clean_train_df['Neighborhood'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
clean_train_df.columns[clean_train_df.dtypes == object]
# Out:
# Index(['HouseStyle', 'Garage_Type', 'Lot_Location', 'FirstExterior',
#        'SecondExterior', 'MasonryVeneer_Type', 'Neighborhood',
#        'Sale_Condition'],
#       dtype='object')

# %%
clean_train_df.isnull().sum()[clean_train_df.isnull().sum()>0]
# Out:
# Garage_Type           81
# MasonryVeneer_Type     8
# dtype: int64

# %%
overall_features = clean_train_df[['Id','Overall_Quality', 'Overall_Condition']]
display(overall_features.info())
display(overall_features.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 1460 non-null   int64
#  1   Overall_Quality    1460 non-null   int64
#  2   Overall_Condition  1460 non-null   int64
# dtypes: int64(3)
# memory usage: 34.3 KB
# None
#    Id  Overall_Quality  Overall_Condition
# 0   1                7                  5
# 1   2                6                  8
# 2   3                7                  5
# 3   4                7                  5
# 4   5                8                  5

# %%
#filling in other missing values 
cols = ["Garage_Type", "MasonryVeneer_Type"]
for col in cols:
    clean_train_df[col].fillna(0, inplace=True)
# Out:
# /Users/adebolaayilumo/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
clean_train_df.isnull().sum()[clean_train_df.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
clean_train_df['HouseStyle'].value_counts().to_frame()
# Out:
#         HouseStyle
# 1Story         726
# 2Story         445
# 1.5Fin         154
# SLvl            65
# SFoyer          37
# 1.5Unf          14
# 2.5Unf          11
# 2.5Fin           8

# %%
clean_train_df['No_of_Bedrooms'].value_counts().to_frame()
# Out:
#    No_of_Bedrooms
# 3             804
# 2             358
# 4             213
# 1              50
# 5              21
# 6               7
# 0               6
# 8               1

# %%
exterior_features = clean_train_df[['FirstExterior', 'SecondExterior']]
display(exterior_features.info())
display(exterior_features.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   FirstExterior   1460 non-null   object
#  1   SecondExterior  1460 non-null   object
# dtypes: object(2)
# memory usage: 22.9+ KB
# None
#   FirstExterior SecondExterior
# 0       VinylSd        VinylSd
# 1       MetalSd        MetalSd
# 2       VinylSd        VinylSd
# 3       Wd Sdng        Wd Shng
# 4       VinylSd        VinylSd

# %%
bathroom_features = clean_train_df[['Full_Bath', 'Half_Bath']]
display(bathroom_features.info())
display(bathroom_features.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Full_Bath  1460 non-null   int64
#  1   Half_Bath  1460 non-null   int64
# dtypes: int64(2)
# memory usage: 22.9 KB
# None
#    Full_Bath  Half_Bath
# 0          2          1
# 1          2          0
# 2          2          1
# 3          1          0
# 4          2          1

# %%
sum_column = clean_train_df["LivingArea_Sqft"] + clean_train_df["1stFloor_Sqft"] + clean_train_df["2ndFloor_Sqft"]
clean_train_df["Total_Sqft"] = sum_column
print(clean_train_df)
# Out:
#         Id HouseStyle  No_of_Bedrooms  Full_Bath  Half_Bath Garage_Type  \
# 0        1     2Story               3          2          1      Attchd
# 1        2     1Story               3          2          0      Attchd
# 2        3     2Story               3          2          1      Attchd
# 3        4     2Story               3          1          0      Detchd
# 4        5     2Story               4          2          1      Attchd
# ...    ...        ...             ...        ...        ...         ...
# 1455  1456     2Story               3          2          1      Attchd
# 1456  1457     1Story               3          2          0      Attchd
# 1457  1458     2Story               4          2          0      Attchd
# 1458  1459     1Story               2          1          0      Attchd
# 1459  1460     1Story               3          1          1      Attchd
#
#       LivingArea_Sqft  1stFloor_Sqft  2ndFloor_Sqft  Total_Sqft  ...  \
# ...

# %%
clean_train_df.shape
# Out:
# (1460, 21)

# %%
clean_train_df.describe()
# Out:
#                 Id  No_of_Bedrooms    Full_Bath    Half_Bath  LivingArea_Sqft  \
# count  1460.000000     1460.000000  1460.000000  1460.000000      1460.000000
# mean    730.500000        2.866438     1.565068     0.382877      1515.463699
# std     421.610009        0.815778     0.550916     0.502885       525.480383
# min       1.000000        0.000000     0.000000     0.000000       334.000000
# 25%     365.750000        2.000000     1.000000     0.000000      1129.500000
# 50%     730.500000        3.000000     2.000000     0.000000      1464.000000
# 75%    1095.250000        3.000000     2.000000     1.000000      1776.750000
# max    1460.000000        8.000000     3.000000     2.000000      5642.000000
#
#        1stFloor_Sqft  2ndFloor_Sqft    Total_Sqft    YearBuilt  \
# count    1460.000000    1460.000000   1460.000000  1460.000000
# mean     1162.626712     346.992466   3025.082877  1971.267808
# std       386.587738     436.528436   1045.522787    30.202904
# ...

# %%
sqft_df = clean_train_df[['LivingArea_Sqft','1stFloor_Sqft','2ndFloor_Sqft', 'Sale_Price']]
sqft_df = sqft_df[~sqft_df['Sale_Price'].isnull()]
sqft_vars = list(sqft_df)
del sqft_vars[-1]

sqft_summary = []

for sqft_type in sqft_vars:
    corr_val = np.corrcoef(sqft_df[sqft_type], sqft_df['Sale_Price'])[1][0]
    sqft_summary.append(corr_val)
    
pd.DataFrame([sqft_summary], columns=sqft_vars, index=['SalePrice Correlation'])
# Out:
#                        LivingArea_Sqft  1stFloor_Sqft  2ndFloor_Sqft
# SalePrice Correlation         0.708624       0.605852       0.319334

# %%
sqft_df
# Out:
#       LivingArea_Sqft  1stFloor_Sqft  2ndFloor_Sqft  Sale_Price
# 0                1710            856            854      208500
# 1                1262           1262              0      181500
# 2                1786            920            866      223500
# 3                1717            961            756      140000
# 4                2198           1145           1053      250000
# ...               ...            ...            ...         ...
# 1455             1647            953            694      175000
# 1456             2073           2073              0      210000
# 1457             2340           1188           1152      266500
# 1458             1078           1078              0      142125
# 1459             1256           1256              0      147500
#
# [1460 rows x 4 columns]

# %%
# 4. Create a features DataFrame from the list 
features_df = pd.DataFrame(clean_train_df, columns=['Id','HouseStyle','No_of_Bedrooms', 'Full_Bath', 'Half_Bath','Total_Sqft','Garage_Type','FirstExterior', 'SecondExterior'])
features_df.set_index(features_df['Id'], inplace=True)
features_df=features_df[['Id','HouseStyle','No_of_Bedrooms', 'Full_Bath', 'Half_Bath','Total_Sqft','Garage_Type','FirstExterior', 'SecondExterior']]
features_df
# Out:
#         Id HouseStyle  No_of_Bedrooms  Full_Bath  Half_Bath  Total_Sqft  \
# Id
# 1        1     2Story               3          2          1        3420
# 2        2     1Story               3          2          0        2524
# 3        3     2Story               3          2          1        3572
# 4        4     2Story               3          1          0        3434
# 5        5     2Story               4          2          1        4396
# ...    ...        ...             ...        ...        ...         ...
# 1456  1456     2Story               3          2          1        3294
# 1457  1457     1Story               3          2          0        4146
# 1458  1458     2Story               4          2          0        4680
# 1459  1459     1Story               2          1          0        2156
# 1460  1460     1Story               3          1          1        2512
#
#      Garage_Type FirstExterior SecondExterior
# Id
# 1         Attchd       VinylSd        VinylSd
# ...

# %% [markdown]
# # Clean the Test Dataset

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# ...

# %%
clean_testdata_df = { 'Id': 'Id',
                 'HouseStyle': 'HouseStyle',
                 'BedroomAbvGr': 'No_of_Bedrooms',
                 'FullBath': 'Full_Bath',
                 'HalfBath': 'Half_Bath',
                 'GarageType': 'Garage_Type',
                 'GrLivArea': 'LivingArea_Sqft',
                 '1stFlrSF': '1stFloor_Sqft',
                 '2ndFlrSF':'2ndFloor_Sqft' ,
                 'LotConfig': 'Lot_Location',
                 'YearBuilt': 'YearBuilt',
                 'YearRemodAdd': 'Year_Remodeled',
                 'Exterior1st': '1stExterior',
                 'Exterior2nd': '2ndExterior',
                 'MasVnrType': 'MasonryVeneer_Type',
                 'Neighborhood': 'Neighborhood',
                 'OverallQual': 'Overall_Quality',
                 'OverallCond': 'Overall_Condition',
                 'SaleCondition': 'Sale_Condition'
    
}
test_df.rename(columns =clean_testdata_df, inplace = True)
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  Sale_Condition
# ...

# %%
clean_test_df = test_df[[
    'Id','HouseStyle','No_of_Bedrooms','Full_Bath','Half_Bath','Garage_Type',
    'LivingArea_Sqft','1stFloor_Sqft','2ndFloor_Sqft' ,'Lot_Location','YearBuilt',
    'Year_Remodeled','1stExterior','2ndExterior','MasonryVeneer_Type','Neighborhood',
    'Overall_Quality','Overall_Condition','Sale_Condition'
    ]]

# %%
clean_test_df
# Out:
#         Id HouseStyle  No_of_Bedrooms  Full_Bath  Half_Bath Garage_Type  \
# 0     1461     1Story               2          1          0      Attchd
# 1     1462     1Story               3          1          1      Attchd
# 2     1463     2Story               3          2          1      Attchd
# 3     1464     2Story               3          2          1      Attchd
# 4     1465     1Story               2          2          0      Attchd
# ...    ...        ...             ...        ...        ...         ...
# 1454  2915     2Story               3          1          1         NaN
# 1455  2916     2Story               3          1          1     CarPort
# 1456  2917     1Story               4          1          0      Detchd
# 1457  2918     SFoyer               3          1          0         NaN
# 1458  2919     2Story               3          2          1      Attchd
#
#       LivingArea_Sqft  1stFloor_Sqft  2ndFloor_Sqft Lot_Location  YearBuilt  \
# ...

# %%
clean_test_df.columns[clean_test_df.dtypes == object]
# Out:
# Index(['HouseStyle', 'Garage_Type', 'Lot_Location', '1stExterior',
#        '2ndExterior', 'MasonryVeneer_Type', 'Neighborhood', 'Sale_Condition'],
#       dtype='object')

# %%
clean_test_df.isnull().sum()[clean_test_df.isnull().sum()>0]
# Out:
# Garage_Type           76
# 1stExterior            1
# 2ndExterior            1
# MasonryVeneer_Type    16
# dtype: int64

# %%
overall_features = clean_test_df[['Overall_Quality', 'Overall_Condition']]
display(overall_features.info())
display(overall_features.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Overall_Quality    1459 non-null   int64
#  1   Overall_Condition  1459 non-null   int64
# dtypes: int64(2)
# memory usage: 22.9 KB
# None
#    Overall_Quality  Overall_Condition
# 0                5                  6
# 1                6                  6
# 2                5                  5
# 3                6                  6
# 4                8                  5

# %%
#filling in other missing values 
cols = ["Garage_Type", "MasonryVeneer_Type"]
for col in cols:
    clean_test_df[col].fillna(0, inplace=True)
# Out:
# /Users/adebolaayilumo/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
# fill in with mode
cols2 = ['1stExterior','2ndExterior']
for col in cols2:
    clean_test_df[col].fillna(clean_test_df[col].mode()[0], inplace=True)

# %%
clean_test_df.isnull().sum()[clean_test_df.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
clean_test_df
# Out:
#         Id HouseStyle  No_of_Bedrooms  Full_Bath  Half_Bath Garage_Type  \
# 0     1461     1Story               2          1          0      Attchd
# 1     1462     1Story               3          1          1      Attchd
# 2     1463     2Story               3          2          1      Attchd
# 3     1464     2Story               3          2          1      Attchd
# 4     1465     1Story               2          2          0      Attchd
# ...    ...        ...             ...        ...        ...         ...
# 1454  2915     2Story               3          1          1           0
# 1455  2916     2Story               3          1          1     CarPort
# 1456  2917     1Story               4          1          0      Detchd
# 1457  2918     SFoyer               3          1          0           0
# 1458  2919     2Story               3          2          1      Attchd
#
#       LivingArea_Sqft  1stFloor_Sqft  2ndFloor_Sqft Lot_Location  YearBuilt  \
# ...

# %% [markdown]
# # Connect Pandas to Postgres

# %%
from sqlalchemy import create_engine
from config import db_password
import psycopg2

# %%
db_string = f"postgresql://postgres:{db_password}@housing-prices.ctpruadwlamv.us-east-2.rds.amazonaws.com:5432/housing-prices"
engine = create_engine(db_string)

# %%
clean_train_df.to_sql(name='clean_train', con=engine, if_exists='append',index=False)

# %%
clean_test_df.to_sql(name='clean_test', con=engine, if_exists='append',index=False)

# %%
features_df.to_sql('features',con=engine, if_exists='append',index=False)

# %%
overall_features.to_sql('clean_train_df',con=engine, if_exists='append',index=False)
